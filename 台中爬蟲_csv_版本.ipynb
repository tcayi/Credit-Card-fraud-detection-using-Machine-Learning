# %% [markdown]
# <a href="https://colab.research.google.com/github/tcayi/Credit-Card-fraud-detection-using-Machine-Learning/blob/main/%E5%8F%B0%E4%B8%AD%E7%88%AC%E8%9F%B2_csv_%E7%89%88%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 從雲端資料讀取的方法，好像有個drive的方式
# from google.colab import drive
# drive.mount('/content/drive')

# #先保留 zipfile，應該可以寫個迴圈做更輕鬆處理的做法，而不是Opendata的資料下載後還要一個一個解壓縮
# import zipfile

import pandas as pd
import numpy as np
import os

#資料來源透過內政部資料下載不動產成交案例的OpenData下載 (沒有登入的免費版本，好像沒有經緯度的部分，尋找API中)

#台中歷年資料 101-113直到6月初  (檔案中lvr_A 是土地買賣，B是租賃查詢，C是預售屋))，台中較舊沒有資料，就沒有放
# X前面的字體 A:台北 B:台中 C:基隆
# x_lvr_land_a：房屋買賣交易
# x_lvr_land_b：新成屋交易
# x_lvr_land_c：租房交易


#已登記日期為主，跟網站上的好像報的是不同日期
#114_1 = 發布日期20250401 (登記日期 114年3月11日至 114年3月20日之買賣案件，及訂約日期 114年2月11日至 114年2月20日之租賃案件，及交易日期114年2月11日至 114年2月20日之預售屋案件
#114_2 = 發布日期20250411 (登記日期 114年3月21日至 114年3月31日之買賣案件，及訂約日期 114年2月21日至 114年2月28日之租賃案件，及交易日期114年2月21日至 114年2月28日之預售屋案件
#114_3 = 發布日期20250421 (登記日期 114年4月1日至 114年4月10日之買賣案件，及訂約日期 114年3月1日至 114年3月10日之租賃案件，及交易日期114年3月1日至 114年3月10日之預售屋案件
#114_4 = 發布日期20250501 (登記日期 114年4月11日至 114年4月20日之買賣案件，及訂約日期 114年3月11日至 114年3月20日之租賃案件，及交易日期114年3月11日至 114年3月20日之預售屋案件
#114_5 = 發布日期20250511 (登記日期 114年4月21日至 114年4月30日之買賣案件，及訂約日期 114年3月21日至 114年3月31日之租賃案件，及交易日期114年3月21日至 114年3月31日之預售屋案件
#114_6 = 發布日期20250521 (登記日期 114年5月1日至 114年5月10日之買賣案件，及訂約日期 114年4月1日至 114年4月10日之租賃案件，及交易日期114年4月1日至 114年4月10日之預售屋案件
#114_7 = [本期] 發布日期114年6月1日 (登記日期 114年5月11日至 114年5月20日之買賣案件，及訂約日期 114年4月11日至 114年4月20日之租賃案件，及交易日期114年4月11日至 114年4月20日之預售屋案件)

# low_memory = low_memory=False 是在VSCode上出現的message，下方聯結有解釋 (英文)
# https://www.geeksforgeeks.org/pandas-read_csv-low_memory-and-dtype-options/

# 如果跑不動要先將csv 集中到Colab環境中，呼叫的絕對路徑方式好像有差距

df_101c=pd.read_csv('101_3.csv',low_memory=False)
df_101d=pd.read_csv('101_4.csv',low_memory=False)
df_102a=pd.read_csv('102_1.csv',low_memory=False)
df_102b=pd.read_csv('102_2.csv',low_memory=False)
df_102c=pd.read_csv('102_3.csv',low_memory=False)
df_102d=pd.read_csv('102_4.csv',low_memory=False)
df_103a=pd.read_csv('103_1.csv',low_memory=False)
df_103b=pd.read_csv('103_2.csv',low_memory=False)
df_103c=pd.read_csv('103_3.csv',low_memory=False)
df_103d=pd.read_csv('103_4.csv',low_memory=False)
df_104a=pd.read_csv('104_1.csv',low_memory=False)
df_104b=pd.read_csv('104_2.csv',low_memory=False)
df_104c=pd.read_csv('104_3.csv',low_memory=False)
df_104d=pd.read_csv('104_4.csv',low_memory=False)
df_105a=pd.read_csv('105_1.csv',low_memory=False)
df_105b=pd.read_csv('105_2.csv',low_memory=False)
df_105c=pd.read_csv('105_3.csv',low_memory=False)
df_105d=pd.read_csv('105_4.csv',low_memory=False)
df_106a=pd.read_csv('106_1.csv',low_memory=False)
df_106b=pd.read_csv('106_2.csv',low_memory=False)
df_106c=pd.read_csv('106_3.csv',low_memory=False)
df_106d=pd.read_csv('106_4.csv',low_memory=False)
df_107a=pd.read_csv('107_1.csv',low_memory=False)
df_107b=pd.read_csv('107_2.csv',low_memory=False)
df_107c=pd.read_csv('107_3.csv',low_memory=False)
df_107d=pd.read_csv('107_4.csv',low_memory=False)
df_108a=pd.read_csv('108_1.csv',low_memory=False)
df_108b=pd.read_csv('108_2.csv',low_memory=False)
df_108c=pd.read_csv('108_3.csv',low_memory=False)
df_108d=pd.read_csv('108_4.csv',low_memory=False)
df_109a=pd.read_csv('109_1.csv',low_memory=False)
df_109b=pd.read_csv('109_2.csv',low_memory=False)
df_109c=pd.read_csv('109_3.csv',low_memory=False)
df_109d=pd.read_csv('109_4.csv',low_memory=False)
df_110a=pd.read_csv('110_1.csv',low_memory=False)
df_110b=pd.read_csv('110_2.csv',low_memory=False)
df_110c=pd.read_csv('110_3.csv',low_memory=False)
df_110d=pd.read_csv('110_4.csv',low_memory=False)
df_111a=pd.read_csv('111_1.csv',low_memory=False)
df_111b=pd.read_csv('111_2.csv',low_memory=False)
df_111c=pd.read_csv('111_3.csv',low_memory=False)
df_111d=pd.read_csv('111_4.csv',low_memory=False)
df_112a=pd.read_csv('112_1.csv',low_memory=False)
df_112b=pd.read_csv('112_2.csv',low_memory=False)
df_112c=pd.read_csv('112_3.csv',low_memory=False)
df_112d=pd.read_csv('112_4.csv',low_memory=False)
df_113a=pd.read_csv('113_1.csv',low_memory=False)
df_113b=pd.read_csv('113_2.csv',low_memory=False)
df_113c=pd.read_csv('113_3.csv',low_memory=False)
df_113d=pd.read_csv('113_4.csv',low_memory=False)
df_114a=pd.read_csv('114_1.csv',low_memory=False)
df_1141=pd.read_csv('114_a.csv',low_memory=False)
df_1142=pd.read_csv('114_b.csv',low_memory=False)
df_1143=pd.read_csv('114_c.csv',low_memory=False)
df_1144=pd.read_csv('114_d.csv',low_memory=False)
df_1145=pd.read_csv('114_e.csv',low_memory=False)
df_1146=pd.read_csv('114_f.csv',low_memory=False)
df_1147=pd.read_csv('114_g.csv',low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f084e7b14a68> in <cell line: 0>()
#      33 # 如果跑不動要先將csv 集中到Colab環境中，呼叫的絕對路徑方式有差
#      34
# ---> 35 df_101c=pd.read_csv('101_3.csv',low_memory=False)
#      36 df_101d=pd.read_csv('101_4.csv',low_memory=False)
#      37 df_102a=pd.read_csv('102_1.csv',low_memory=False)
#
# ...

# %%
df_101c=pd.read_csv('101_3.csv')
display(df_101c)
# Out:
#                                     鄉鎮市區              交易標的  \
# 0  The villages and towns urban district  transaction sign
# 1                                    豐原區                土地
#
#                                             土地位置建物門牌  \
# 0  land sector position building sector house num...
# 1                                           南陽段897地號
#
#                              土地移轉總面積平方公尺  \
# 0  land shifting total area square meter
# 1                                  134.7
#
#                                 都市土地使用分區  \
# 0  the use zoning or compiles and checks
# 1                                      住
#
#                               非都市土地使用分區                非都市土地使用編定  \
# 0  the non-metropolis land use district  non-metropolis land use
# 1                                   NaN                      NaN
#
#                             交易年月日                   交易筆棟數            移轉層次  \
# 0  transaction year month and day  transaction pen number  shifting level
# ...

# %%
# 將前面的第0行取消掉
df_101c = df_101c.drop([0])
df_101d = df_101d.drop([0])
df_102a = df_102a.drop([0])
df_102b = df_102b.drop([0])
df_102c = df_102c.drop([0])
df_102d = df_102d.drop([0])
df_103a = df_103a.drop([0])
df_103b = df_103b.drop([0])
df_103c = df_103c.drop([0])
df_103d = df_103d.drop([0])
df_104a = df_104a.drop([0])
df_104b = df_104b.drop([0])
df_104c = df_104c.drop([0])
df_104d = df_104d.drop([0])
df_105a = df_105a.drop([0])
df_105b = df_105b.drop([0])
df_105c = df_105c.drop([0])
df_105d = df_105d.drop([0])
df_106a = df_106a.drop([0])
df_106b = df_106b.drop([0])
df_106c = df_106c.drop([0])
df_106d = df_106d.drop([0])
df_107a = df_107a.drop([0])
df_107b = df_107b.drop([0])
df_107c = df_107c.drop([0])
df_107d = df_107d.drop([0])
df_108a = df_108a.drop([0])
df_108b = df_108b.drop([0])
df_108c = df_108c.drop([0])
df_108d = df_108d.drop([0])
df_109a = df_109a.drop([0])
df_109b = df_109b.drop([0])
df_109c = df_109c.drop([0])
df_109d = df_109d.drop([0])
df_110a = df_110a.drop([0])
df_110b = df_110b.drop([0])
df_110c = df_110c.drop([0])
df_110d = df_110d.drop([0])
df_111a = df_111a.drop([0])
df_111b = df_111b.drop([0])
df_111c = df_111c.drop([0])
df_111d = df_111d.drop([0])
df_112a = df_112a.drop([0])
df_112b = df_112b.drop([0])
df_112c = df_112c.drop([0])
df_112d = df_112d.drop([0])
df_113a = df_113a.drop([0])
df_113b = df_113b.drop([0])
df_113c = df_113c.drop([0])
df_113d = df_113d.drop([0])
df_114a = df_114a.drop([0])
df_1141 = df_1141.drop([0])
df_1142 = df_1142.drop([0])
df_1143 = df_1143.drop([0])
df_1144 = df_1144.drop([0])
df_1145 = df_1145.drop([0])
df_1146 = df_1146.drop([0])
df_1147 = df_1147.drop([0])

# %%
#將匯入進來的資料運用pd.concat()串接
df = pd.concat([df_101c,df_101d,df_102a,df_102b,df_102c,df_102d,df_103a,df_103b,df_103c,df_103d,df_104a,df_104b,df_104c,
                df_104d,df_105a,df_105b,df_105c,df_105d,df_106a,df_106b,df_106c,df_106d,
                df_107a,df_107b,df_107c,df_107d,df_108a,df_108b,df_108c,df_108d,
                df_109a,df_109b,df_109c,df_109d,df_110a,df_110b,df_110c,df_110d,
                df_111a,df_111b,df_111c,df_111d,df_112a,df_112b,df_112c,df_112d,
                df_113a,df_113b,df_113c,df_113d,df_114a,df_1141,df_1142,df_1143,
                df_1144,df_1145,df_1146,df_1147],axis=0)

#axis=0 是將資料已row的方式顯示

# %%
#這種方法可以生成city欄位其中以地區分類台北市Taipei(A_lvr_land_A.csv)、新北市New_Taipei(F_lvr_land_A.csv)、台中市Taichung(B_lvr_land_A.csv)、高雄市Kaohsiung(E_lvr_land_A.csv)
# df_A.insert(0, '城市', '台北市')
# df_F.insert(0, '城市', '新北勢')
# df_B.insert(0, '城市', '台中市')

# %%
pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.6/262.6 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 57.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.8/309.8 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 38.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 18.8 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=cca9a005bb16020765a64ab0de08ea8b2eacdfc66d0d9a5a2bd7de6e7674e993
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
# ...

# %%
display(df)
# Out:
#     鄉鎮市區          交易標的             土地位置建物門牌 土地移轉總面積平方公尺 都市土地使用分區 非都市土地使用分區  \
# 1    豐原區            土地             南陽段897地號       134.7        住       NaN
# 1    烏日區            土地          新榮和段141-9地號      174.31        住       NaN
# 2    烏日區            建物       台中市烏日區三榮路二段６７號         0.0      NaN       NaN
# 3    清水區     房地(土地+建物)     台中市清水區和睦路５０巷１３１號       155.5       其他     一般農業區
# 4    新社區     房地(土地+建物)      台中市新社區華豐街３３０之１號       395.0        農     一般農業區
# ..   ...           ...                  ...         ...      ...       ...
# 868  北屯區  房地(土地+建物)+車位  臺中市北屯區瀋陽路一段６５號十三樓之５       16.73        住       NaN
# 869  北屯區  房地(土地+建物)+車位  臺中市北屯區瀋陽路一段６５號十三樓之９       14.65        住       NaN
# 870  北屯區  房地(土地+建物)+車位  臺中市北屯區瀋陽路一段６５號十四樓之９       14.65        住       NaN
# 871  北屯區  房地(土地+建物)+車位  臺中市北屯區瀋陽路一段６５號十五樓之６       16.73        住       NaN
# 872   北區  房地(土地+建物)+車位     臺中市北區進化路５２７號八樓之１       16.36        商       NaN
#
# ...

# %%
# 只選特定區域 (假設)
rslt_df = df.loc[df['鄉鎮市區'] = '北屯區']

# %%
#Pandas 中的 Reporting 測試
from pandas_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-7dbb16276cae> in <cell line: 0>()
#       1 #Pandas 中的 Reporting 測試
# ----> 2 from pandas_profiling import ProfileReport
#       3 profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# ...

# %%
#將中文的欄位先設定成英文dict，到時候再匯入MySQL或MongoDB中變數比較好叫

columns_mapping = {'鄉鎮市區':'towns',
'交易標的':'transaction_sign',
'土地區段位置建物區段門牌':'house_number',
'土地移轉總面積平方公尺':'land_area_square_meter',
'都市土地使用分區':'use_zoning',
'非都市土地使用分區':'land_use_district',
'非都市土地使用編定':'land_use',
'交易年月日':'tx_dt',
 '交易筆棟數':'transaction_pen_number',
 '移轉層次':'shifting_level',
 '總樓層數':'total_floor_number',
 '建物型態':'building_state',
 '主要用途':'main_use',
 '主要建材':'main_materials',
 '建築完成年月':'complete_date',
 '建物移轉總面積平方公尺':'building_area_square_meter',
 '建物現況格局-房':'room_number',
 '建物現況格局-廳':'hall_number',
 '建物現況格局-衛':'health_number',
'建物現況格局-隔間':'compartmented_number',
 '有無管理組織':'manages',
 '總價元':'total_price',
 '單價元平方公尺':'unit_price',
 '車位類別':'berth_category',
 '車位移轉總面積(平方公尺)':'berth_area_square_meter',
'車位總價元':'berth_price',
 '備註':'note',
 '編號':'serial_number',
 '主建物面積':'main_building_area',
 '附屬建物面積':'auxiliary_building_area',
 '陽台面積':'balcony_area',
 '電梯':'elevator'
                  }
analysis_columns = ['city','towns','main_use','use_zoning','total_price','building_area_square_meter',
                                     'main_building_area',
                                     'tx_dt','unit_price','room_number','hall_number','health_number']
columns_type = {'total_price': 'int','unit_price':'float','building_area_square_meter':'float',
                                      'main_building_area': 'float',
                                      'room_number': 'int','hall_number': 'int','health_number': 'int'}
